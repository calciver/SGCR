# %% [markdown]
# <a href="https://colab.research.google.com/github/calciver/SGCR/blob/master/SGCR_Colab_Version_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download the dataset and unzip

# %%
# !pip install -q patool
import patoolib
import os

#Organise our files
ROOT_DIR = os.path.abspath("/content")
# !git clone https://github.com/calciver/SGCR.git  
WORK_DIR = os.path.abspath("/content/SGCR")
os.chdir(WORK_DIR)


patoolib.extract_archive("train_and_val_images.zip")  
IMAGE_DIR = os.path.abspath("/content/radiology/train_and_val_images")
# Out:
#      |████████████████████████████████| 81kB 23.7MB/s
# Cloning into 'SGCR'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 70 (delta 17), reused 7 (delta 3), pack-reused 36
# Unpacking objects: 100% (70/70), done.
# patool: Extracting train_and_val_images.zip ...
# patool: running /usr/bin/7z x -o./Unpack_c8s99c3p -- train_and_val_images.zip
# patool: ... train_and_val_images.zip extracted to `train_and_val_images' (multiple files in root).

# %% [markdown]
# # Load the libraries

# %%
import numpy as np
import tensorflow as tf
from keras import optimizers
import csv
from keras.layers import Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Sequential
from keras.layers import Dense
from PIL import Image
from keras.utils import to_categorical
from keras.callbacks import TensorBoard
import time
from numpy import random
import os
import matplotlib.pyplot as plt

ROOT_DIR = os.path.abspath("/content")
# !git clone https://github.com/calciver/SGCR.git  
WORK_DIR = os.path.abspath("/content/SGCR")
os.chdir(WORK_DIR)


csv_files_dir = os.path.abspath('/content/SGCR')
train_image_file_dir = os.path.abspath('/content/SGCR/train_and_val_images/train')
val_image_file_dir = os.path.abspath('/content/SGCR/train_and_val_images/val')

os.mkdir('models')
model_directory = os.path.abspath("/content/SGCR/models")

val_csv_filename = 'val.csv'
train_csv_filename = 'train.csv'

#Number of epochs
num_epochs = 10
# Out:
# Using TensorFlow backend.
# Cloning into 'SGCR'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 70 (delta 17), reused 7 (delta 3), pack-reused 36
# Unpacking objects: 100% (70/70), done.

# %% [markdown]
# # Process and Load the data

# %%
#Gets csv files directory and csv filename and returns rows in csv files which are image names and lables
def load_csv (csv_files_dir, csv_filename) :
    csv_rows = []
    with open(csv_files_dir + '/' + csv_filename, newline='') as csvFile:
        reader = csv.reader(csvFile, delimiter=',')
        for row in reader:
            csv_rows.append(row)
    #print('csv_rows[-1] : ', csv_rows[-1], len(csv_rows))
    return csv_rows

#returns numpy arrays of images and labels for each batch
def load_data (batch, image_dir):
    image_array = []
    label_array = []
    for b in batch:
        image_array.append(np.asarray(Image.open(image_dir + '/' + b[0])))
        label_array.append(b[1])
    labels = np.array(label_array)
    images = np.array(image_array)
    return images, labels

#Preparing training data

train_imagename_label_pairs = load_csv(csv_files_dir, train_csv_filename)
#shuffle images and labels foe each epoch
random.shuffle(train_imagename_label_pairs)
[train_images, train_labels ] = load_data(train_imagename_label_pairs, train_image_file_dir)

#number of training data size
batch_size_train= len(train_imagename_label_pairs)
image_shape = train_images.shape
train_images2 = np.reshape(train_images, [-1, image_shape[1], image_shape[2], 1])
train_labels1 = to_categorical(train_labels)
train_labels2 = np.reshape(train_labels1, [batch_size_train, 2])

#Preparing validation data

val_imagename_label_pairs = load_csv(csv_files_dir, val_csv_filename)
random.shuffle(val_imagename_label_pairs)
[val_images, val_labels] = load_data(val_imagename_label_pairs, val_image_file_dir)

#number of training validation size
batch_size_val = len(val_imagename_label_pairs)
image_shape = val_images.shape
val_images2 = np.reshape(val_images, [-1, image_shape[1], image_shape[2], 1])
val_labels1 = to_categorical(val_labels)
val_labels2 = np.reshape(val_labels1, [batch_size_val, 2])

# %% [markdown]
# # Build the Model

# %%
#This class is used to merge traing accuracy and validation accuracy graphs in Tensorboard

class TrainValTensorBoard(TensorBoard):
    def __init__(self, log_dir='/logs', **kwargs):
        # Make the original `TensorBoard` log to a subdirectory 'training'
        training_log_dir = os.path.join(log_dir, 'training')
        super(TrainValTensorBoard, self).__init__(training_log_dir, **kwargs)

        # Log the validation metrics to a separate subdirectory
        self.val_log_dir = os.path.join(log_dir, 'validation')

    def set_model(self, model):
        # Setup writer for validation metrics
        self.val_writer = tf.summary.FileWriter(self.val_log_dir)
        super(TrainValTensorBoard, self).set_model(model)

    def on_epoch_end(self, epoch, logs=None):
        # Pop the validation logs and handle them separately with
        # `self.val_writer`. Also rename the keys so that they can
        # be plotted on the same figure with the training metrics
        logs = logs or {}
        val_logs = {k.replace('val_', ''): v for k, v in logs.items() if k.startswith('val_')}
        for name, value in val_logs.items():
            summary = tf.Summary()
            summary_value = summary.value.add()
            if isinstance(value, np.ndarray):
                summary_value.simple_value = value.item()
            else:
                summary_value.simple_value = value
            summary_value.tag = name
            self.val_writer.add_summary(summary, epoch)
        self.val_writer.flush()

        # Pass the remaining logs to `TensorBoard.on_epoch_end`
        logs = {k: v for k, v in logs.items() if not k.startswith('val_')}
        super(TrainValTensorBoard, self).on_epoch_end(epoch, logs)

    def on_train_end(self, logs=None):
        super(TrainValTensorBoard, self).on_train_end(logs)
        self.val_writer.close()




#ploting 4 different categories
def show_samples(input_image , input_pairs  ,image_dir):

    correct_pneumonia=[]
    incorrect_pneumonia=[]
    correct_normal=[]
    incorrect_normal=[]
    prediction = np.empty(0)
#model.predict returns 2 values which are predictions of each label
    pred =model.predict(x=input_image, batch_size=None , verbose=0, steps=None)
    prediction = np.append(prediction,pred)
    prediction_list = prediction.tolist()
    zero_labels_predicted = prediction_list[::2]
    one_labels_predicted = prediction_list[1::2]

    for i in range(len(input_pairs)) :

        if input_pairs[i][1] == '1' :
            if one_labels_predicted[i] > 0.50 :
                print("correct_pneumonia : " , input_pairs[i][0])
                correct_pneumonia.append(input_pairs[i][0])
            elif one_labels_predicted[i] <0.50 :
                incorrect_pneumonia.append(input_pairs[i][0])

        elif input_pairs[i][1] == '0' :
            if zero_labels_predicted[i] > 0.50 :
                correct_normal.append(input_pairs[i][0])
                print("correct normal : ", input_pairs[i][0])
            elif zero_labels_predicted[i] < 0.50 :
                incorrect_normal.append(input_pairs[i][0])

#ploting images
    if correct_pneumonia != [] :
        plt.subplot(2, 2, 1)
        img = plt.imread(image_dir +'/' + correct_pneumonia[0])
        plt.imshow(img, cmap='gray')
        plt.title('correct_pneumonia')

    if incorrect_pneumonia != [] :
        plt.subplot(2, 2, 2)
        img = Image.open(image_dir + '/' + incorrect_pneumonia[0])
        plt.imshow(img, cmap='gray')
        plt.title('incorrect_pneumonia')

    if correct_normal !=[] :
        plt.subplot(2, 2, 3)
        img = Image.open(image_dir + '/' + correct_normal[0])
        plt.imshow(img, cmap='gray')
        plt.title('correct_normal')

    if incorrect_normal != [] :
        plt.subplot(2, 2, 4)
        img = Image.open(image_dir + '/' + incorrect_normal[0])
        plt.imshow(img, cmap='gray')
        plt.title('incorrect_normal')

    plt.show()


#saving model
def save_model(model):
    # serialize model to JSON
    model_json =  model.to_json()

    if not os.path.exists(model_directory):
        os.mkdir(model_directory)

    model_filename_json =  model_directory+Name+ ".json"
    print(model_filename_json)

    model_filename_h5 = model_directory +Name+ ".h5"

    with open(model_filename_json, "w") as json_file:
        json_file.write(model_json)
    # serialize weights to HDF5
    model.save_weights(model_filename_h5)
    print("Saved model to disk")



#Model Architecture

Name = 'updated_model-{}'.format(int(time.time()))
tensorboard = TrainValTensorBoard(log_dir='logs/{}'.format(Name))

#set up a sequential model
model = Sequential()
#first convolutional layer with 8 channels and kenel size of 7*7
model.add(Conv2D(8, (7, 7), input_shape=(512, 512, 1), kernel_initializer="glorot_normal"))
# tanh activation function
model.add(Activation('tanh'))
#polling layer using Maxpooling of window size 2*2
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(16, (4, 4), kernel_initializer="RandomUniform"))
model.add(Activation('tanh'))
#model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size=(3, 3)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('tanh'))
#model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size=(3, 3)))

model.add(Flatten())
model.add(Dense(64, kernel_initializer="Zeros"))
model.add(Activation('tanh'))
model.add(Dropout(0.2))

model.add(Dense(32, kernel_initializer="glorot_normal"))
model.add(Activation('tanh'))

model.add(Dense(2))
model.add(Activation('softmax'))

#Summarize Model and Visualize Model
model.summary()

#Configures the model for training using  existing loss function 'categorical_crossnetropy' .
#'Adam' optimizer with learning rate of 0.0005.
#and 'categorical_accuracy' as metrices to be evaluated by the model during training and testing.
adam = optimizers.Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, decay=0.00001, amsgrad=True)
model.compile(loss="categorical_crossentropy",
              optimizer=adam,
              metrics=["categorical_accuracy"])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0813 07:56:53.967590 140425135777664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0813 07:56:53.974055 140425135777664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0813 07:56:53.983527 140425135777664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0813 07:56:54.009768 140425135777664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0813 07:56:54.012512 140425135777664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0813 07:56:54.061149 140425135777664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0813 07:56:54.071044 140425135777664 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0813 07:56:54.134407 140425135777664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 506, 506, 8)       400
# _________________________________________________________________
# activation_1 (Activation)    (None, 506, 506, 8)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 253, 253, 8)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 250, 250, 16)      2064
# _________________________________________________________________
# activation_2 (Activation)    (None, 250, 250, 16)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 83, 83, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 81, 81, 32)        4640
# _________________________________________________________________
# activation_3 (Activation)    (None, 81, 81, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 27, 27, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 23328)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                1493056
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# activation_5 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 66
# _________________________________________________________________
# activation_6 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 1,502,306
# Trainable params: 1,502,306
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model

# %%
history = model.fit(x=train_images2, y=train_labels2,  epochs = num_epochs ,batch_size=10,
                    validation_data=[val_images2, val_labels2],
                     verbose=2 , shuffle=True, callbacks=[tensorboard])


#ploting 4 samples of each catagory : correct_pneumonia ,incorrect_pneumonia, correct_normal, incorrect_normal
#if you can not see some of these categories it means model did not predict any samples of that categories
show_samples(train_images2 ,train_imagename_label_pairs , image_dir = train_image_file_dir)


#Saving Model
dir = os.getcwd()
save_model(model)
# Out:
# W0813 07:56:54.403734 140425135777664 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 400 samples, validate on 400 samples
# W0813 07:56:57.557728 140425135777664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W0813 07:56:57.558953 140425135777664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Epoch 1/10
#  - 6s - loss: 0.4611 - categorical_accuracy: 0.7950 - val_loss: 0.1375 - val_categorical_accuracy: 0.9425
# Epoch 2/10
#  - 2s - loss: 0.0462 - categorical_accuracy: 0.9925 - val_loss: 0.0984 - val_categorical_accuracy: 0.9575
# Epoch 3/10
#  - 2s - loss: 0.0721 - categorical_accuracy: 0.9750 - val_loss: 0.0618 - val_categorical_accuracy: 0.9850
# Epoch 4/10
#  - 2s - loss: 0.0238 - categorical_accuracy: 0.9950 - val_loss: 0.0622 - val_categorical_accuracy: 0.9725
# Epoch 5/10
#  - 2s - loss: 0.0292 - categorical_accuracy: 0.9900 - val_loss: 0.0636 - val_categorical_accuracy: 0.9750
# Epoch 6/10
#  - 2s - loss: 0.0073 - categorical_accuracy: 1.0000 - val_loss: 0.0453 - val_categorical_accuracy: 0.9850
# Epoch 7/10
#  - 2s - loss: 0.0027 - categorical_accuracy: 1.0000 - val_loss: 0.0684 - val_categorical_accuracy: 0.9750
# Epoch 8/10
#  - 2s - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 0.0703 - val_categorical_accuracy: 0.9750
# Epoch 9/10
#  - 2s - loss: 0.0012 - categorical_accuracy: 1.0000 - val_loss: 0.0675 - val_categorical_accuracy: 0.9775
# Epoch 10/10
#  - 2s - loss: 0.0011 - categorical_accuracy: 1.0000 - val_loss: 0.0739 - val_categorical_accuracy: 0.9750
# correct_pneumonia :  6fdc7f46-9466-4a4b-b9ce-46db674cfb34.png
# correct_pneumonia :  812cb889-27e8-49c2-a4cd-a03773cfdb61.png
# correct_pneumonia :  35555536-4cf7-4f87-bfe2-8af308264f73.png
# correct_pneumonia :  1d06aef5-4b70-4148-82c0-9a7c156a274e.png
# correct normal :  0cb05380-5ae8-46de-8585-41b5323d7c65.png
# correct normal :  8f88e942-6de5-4c75-96eb-edff7ded7a8d.png
# correct_pneumonia :  3e5e1e9c-4b31-416a-a068-a4e2fc100f10.png
# correct normal :  c5a27c73-aef3-407e-9724-333e97a583c9.png
# correct normal :  b5714c0f-6d0f-4c56-833f-8b83f19e982a.png
# correct_pneumonia :  a6ce14dd-8fb9-4a66-bd5b-caa7ec96188c.png
# correct_pneumonia :  b9f6627a-8842-4e66-a08e-9302975867b6.png
# correct_pneumonia :  4d49d9a9-ce3d-4a0d-81a8-667552d64163.png
# correct normal :  3a3e5ddf-0b42-4c84-b13b-8e3ac1e8b2c0.png
# correct_pneumonia :  e37b7861-47ab-4671-bea2-87619e92c292.png
# correct normal :  b7fe2048-abe7-4f69-b82a-ed93c354a8aa.png
# correct_pneumonia :  668c7bea-ca06-4131-9567-33078f889aa0.png
# correct_pneumonia :  739597a4-836a-4591-8ef2-f912a5822a44.png
# correct normal :  b402b80c-0be4-4c25-80be-d9ace219c83b.png
# correct_pneumonia :  8d7a4925-c838-449c-bb08-8e7699322366.png
# correct_pneumonia :  8ca3384a-3b54-4b22-8c97-628d45a715ab.png
# correct normal :  47cb63e4-4f88-40b7-b4d8-725fdc053c28.png
# correct_pneumonia :  f326a7ef-e7f7-43e0-8c9b-e8ab6033a567.png
# correct normal :  c48ee568-69ac-49f0-92c4-36129b1414b1.png
# correct normal :  4005e782-c12e-4657-9b29-1707ee6eb08a.png
# correct_pneumonia :  56a60ddd-66be-4e4c-8612-8916e2efedee.png
# correct normal :  56a9a226-789b-428e-a1bd-303f4d7a2f1e.png
# correct normal :  bca62fcd-acd1-4ffb-8e1e-fabd4f7c400f.png
# correct_pneumonia :  2721b917-061a-489b-8580-db98f0e80d60.png
# correct normal :  6ea77647-dfcc-46bc-b15f-d41dd2349037.png
# correct_pneumonia :  7257e3de-ff3d-4b37-9450-937abfae06dd.png
# correct_pneumonia :  50908a8f-e286-4304-8d97-562654d734c4.png
# correct_pneumonia :  4139d848-af6d-4264-84ee-599cece63d48.png
# correct normal :  36f51cc5-a28d-48f0-a086-df424f7f2c94.png
# correct_pneumonia :  b8a8cb09-03d8-4748-933c-49d15073062e.png
# correct_pneumonia :  c3b54bc5-16d8-4877-a601-7b3995764e72.png
# correct_pneumonia :  1013ded6-9505-4e1b-a923-f263ad013d0e.png
# correct normal :  543f4f16-4b7f-43bc-8d44-da66513c58b0.png
# correct_pneumonia :  89092a09-18b7-450b-a7b0-58cd6c147919.png
# correct normal :  0cb52e59-3b50-41fb-a022-5b24741dbcfc.png
# correct normal :  b086dfcf-4704-41a5-bdf7-22139c5d0711.png
# correct normal :  3496cccd-1600-4ae9-920f-a5bf7919801c.png
# correct normal :  85708ae1-d69e-4153-bdad-ced31dfaf486.png
# correct_pneumonia :  c8f3473c-8c28-4d6a-8565-a12479d2623c.png
# correct normal :  7c1a130b-a944-431a-a2b1-735483a46c12.png
# correct normal :  5a8415b5-f658-4d37-8144-1aa22420f84f.png
# correct_pneumonia :  d4a1e300-9173-4d57-aaa5-9622e6b6045b.png
# correct_pneumonia :  bd59abda-3e57-4be0-9140-22c8f6de8c3c.png
# correct normal :  f8b2aff8-bcb0-4a58-a3e6-7c52e2334032.png
# correct normal :  abda22a1-7761-4590-a1a8-132e093c54f2.png
# correct normal :  76f00430-861f-4370-9e06-dd5b9692b669.png
# correct_pneumonia :  ec2c0f94-df7e-4de8-83e3-4ee9574c06b4.png
# correct_pneumonia :  702a40d1-bd1d-4eb2-b3b4-89f8a34b3ca6.png
# correct normal :  bb10de59-4206-46ca-b28d-c0750d460829.png
# correct normal :  b01c73b4-b417-4f83-8996-6448caa89c0e.png
# correct_pneumonia :  9df0ffa3-c37d-4058-98ae-a7fd8c5cb8ed.png
# correct normal :  11fcbe52-87f7-4074-85ac-153d5f255e35.png
# correct_pneumonia :  928aaa10-715f-4b4f-a1df-16f16310b20e.png
# correct normal :  bfb48b34-fe9a-4f31-bb5a-27ffe55a49fb.png
# correct_pneumonia :  199ad34d-2478-4948-9f8b-91889c0a4c01.png
# correct_pneumonia :  cbc35978-c3ec-4146-a5d3-8c89ce5a80c0.png
# correct normal :  52ec4779-e0e9-4b01-8b61-a2222cb76a10.png
# correct_pneumonia :  b7268bc2-00d9-4026-9423-2d91a6e22901.png
# correct_pneumonia :  f54f2bdd-5ae9-4fa1-b411-fee73631f191.png
# correct normal :  e92d7e53-f191-41af-a86b-8da6c7734386.png
# correct normal :  70a2c018-870c-4a1a-b3d3-d2647df5d30e.png
# correct_pneumonia :  73d4c4ab-415a-4508-a293-6b30f0df5a1e.png
# correct_pneumonia :  481285a5-9df3-4824-a806-67d6404e287c.png
# correct normal :  1c807df9-7cf0-4f02-bb16-7ad88384ef2e.png
# correct normal :  142c7419-9cd2-4436-8860-cd2c4355abff.png
# correct_pneumonia :  5e70d50b-1b44-4ae5-8c7f-f66ebda228f0.png
# correct_pneumonia :  403f65d5-6590-4cee-8b94-134683648f09.png
# correct_pneumonia :  524d6970-d373-404d-b6d7-16f4744a6220.png
# correct normal :  d9245b95-1261-4dd6-88a8-2c9a69578b0e.png
# correct_pneumonia :  e598870e-3a8d-4713-addb-10299161a823.png
# correct_pneumonia :  de2a97a6-b1f4-4f92-8bf4-3ebe503bf238.png
# correct normal :  80b493e1-a3a6-47a2-ae68-6a502c081507.png
# correct normal :  d5835755-52dd-4a9d-a70e-6a49fcbbe1c8.png
# correct_pneumonia :  e14d98d0-6805-45cb-b4c2-2edeba5965b8.png
# correct_pneumonia :  8760bcf7-6545-4d43-8996-39d5abe8653e.png
# correct normal :  c88d5bf1-aac9-4d2e-87ab-c3a0d8028f12.png
# correct normal :  96f4aeed-716c-4db1-9f81-a186c991855e.png
# correct_pneumonia :  6bbaf85d-e321-4e84-9524-4859004a661c.png
# correct_pneumonia :  798f3843-7acf-4f6e-84a5-dee0652be5f7.png
# correct_pneumonia :  567de77a-f14c-44c5-884f-c33fb1b399c4.png
# correct normal :  b6862fc0-31f9-4091-b8b1-256192168a0f.png
# correct_pneumonia :  781c920e-e6fa-409a-9e97-ac57fcaad24f.png
# correct normal :  7a8dd22c-7af7-428c-a043-578390fc6fa1.png
# correct normal :  a65ddf29-a6d5-430b-8096-4528c45b47b1.png
# correct_pneumonia :  fa2932b5-02fa-4d1a-b2c6-3db35049e65a.png
# correct_pneumonia :  17fc4b35-5736-4105-a316-ae5b5eb18b60.png
# correct_pneumonia :  df4470f6-216e-4636-9f88-47e3adca6e56.png
# correct normal :  051c2709-fbbf-408f-aa19-c869e16a79e2.png
# correct_pneumonia :  236f9fa0-0a74-492d-b9ae-45f0d685ca9b.png
# correct normal :  3993a64f-ab45-4594-abe9-2807e19a1d71.png
# correct_pneumonia :  af863aa9-a9a6-46a7-9180-96339865ef2a.png
# correct_pneumonia :  28eaff00-5fb7-40ee-8206-9d2ff5b081e0.png
# correct normal :  bb6164ee-9b30-4b94-85ca-5f9d94b2ce4a.png
# correct normal :  f7bd2b79-ca7e-4787-9d78-7041d7aa7498.png
# correct normal :  9a2accbb-06fe-4051-9542-2fa5f0c9e261.png
# correct_pneumonia :  5313d411-d611-4c8a-af40-0f075d6d96f6.png
# correct_pneumonia :  9e030d59-a98d-4ab2-8870-bdf1499b2bd8.png
# correct_pneumonia :  c1ca4417-83a6-43a7-a9bf-7d9587e7f14f.png
# correct normal :  00a05408-8291-4231-886e-13763e103161.png
# correct_pneumonia :  d8578918-1047-496a-b9f1-36ae4d0e53da.png
# correct_pneumonia :  4e3127db-cddc-4559-ab99-211baf0ec9e5.png
# correct_pneumonia :  2c7ce8e8-56b1-43a7-b955-7e9669ecab45.png
# correct normal :  d471c394-f44a-47a4-9e41-6a651b8916cc.png
# correct normal :  5e0d73fb-b207-4bab-a1e5-9d6b3163520e.png
# correct_pneumonia :  fe560784-0eb3-453c-b61b-58350fce5297.png
# correct_pneumonia :  49bf391c-a623-4e5d-b6e6-818f85cd52d0.png
# correct_pneumonia :  d5085a38-b7ee-45b6-a0a2-a08d706927ed.png
# correct normal :  f26f795e-e989-40ce-a076-5763295ce46b.png
# correct normal :  a445b3e6-a5ab-4eda-93d8-7f26d4076748.png
# correct normal :  ea1cf22d-0ec1-4820-86ed-a2bce81fa924.png
# correct normal :  b1976cfc-3bae-4bae-a968-4892e6f953ca.png
# correct_pneumonia :  339c5854-b7d5-468e-9a0c-6410c3b13e65.png
# correct normal :  7f9859ae-f79c-495a-b5ab-f717e2bde686.png
# correct_pneumonia :  f566c3b0-cfd0-4857-8155-6e4c44e5c442.png
# correct_pneumonia :  aa5a56da-81dd-4703-a2b4-fff5b215f1bf.png
# correct normal :  45877324-19f1-49c8-90f2-037d0a6ebfae.png
# correct_pneumonia :  582dedfc-19d7-446a-acd3-b8a7081ae664.png
# correct normal :  b72afa3e-644b-479a-845d-14fe8351cdb0.png
# correct normal :  33df5e75-0b13-4c2b-b217-a0b32e3fc396.png
# correct_pneumonia :  7a5cdc7a-bcde-42bb-b2d9-02b9b0c740c7.png
# correct normal :  71c67893-6acf-435b-b80d-9100ad2e5d2e.png
# correct_pneumonia :  bebc91e5-e9df-44c0-ad4f-305cddf7d98c.png
# correct_pneumonia :  a926f112-b852-4ed9-9da8-9b3ae9282d39.png
# correct normal :  7307c83f-63e1-46e1-9400-8d1eac241510.png
# correct normal :  faa89d54-2079-4711-9d65-1c9aa3f58f3f.png
# correct normal :  77bcb2f3-2dfb-4ed7-b88a-b21ad2c87df3.png
# correct_pneumonia :  d7d90260-5815-4af3-b1cd-7a90bf2fa101.png
# correct_pneumonia :  8df428dd-9cdc-40a6-89ef-a951cab06cd8.png
# correct_pneumonia :  770ee884-c29b-4e94-92d4-eb3a5431d976.png
# correct_pneumonia :  27c98d87-8bda-4d17-847a-2732aa50e55c.png
# correct_pneumonia :  4522d490-b6c8-42f3-907d-d7182a790487.png
# correct_pneumonia :  3ea0e730-1b82-4184-a4b7-b2101e40fc93.png
# correct_pneumonia :  f4c1d5e2-95aa-46f1-9815-10bf70f564d1.png
# correct normal :  2c917d3a-95cb-4c11-802c-f83e28cb37bc.png
# correct_pneumonia :  5b1a17e6-6660-4928-847d-2e7a3f7637a2.png
# correct_pneumonia :  29fbf731-2297-4336-8b59-f3399684c486.png
# correct_pneumonia :  f3f4d035-b090-452c-9c40-73d65f1b1940.png
# correct normal :  eb10b7c7-fc94-488a-a5a9-704876d78ebb.png
# correct_pneumonia :  83c5ef04-77c4-4584-948a-1c6a6ba49444.png
# correct_pneumonia :  543de894-dad3-486d-baa6-fd919aebb7be.png
# correct_pneumonia :  68cad8ac-5e8e-45d8-ab2f-8a119580087d.png
# correct_pneumonia :  a694ac65-d011-4e71-b6f8-653258278b3f.png
# correct_pneumonia :  b406c96d-da7b-4f8e-a9ac-88131cefa21d.png
# correct normal :  cf8aa442-74cf-4610-8b1d-980d662bdcc4.png
# correct_pneumonia :  f14a89e5-643f-403b-9147-88eabb3af0a5.png
# correct_pneumonia :  47335c95-e088-4cd8-9dee-60216fd8e185.png
# correct normal :  8aa93e86-e189-4412-ba91-725813f54b56.png
# correct normal :  b45e1b50-d497-4b91-9b79-5050fd0e6800.png
# correct_pneumonia :  58c3c006-1f48-458f-b469-4afcef2b8e76.png
# correct normal :  b9fd29b2-1444-49d9-83b9-2716cc2b3e50.png
# correct normal :  ec494de2-73b0-4ec6-9038-217175b06392.png
# correct_pneumonia :  d47c2f5c-da47-4e36-8534-f2cd9b52f5c2.png
# correct_pneumonia :  3617f75e-3204-427a-b4e9-4703d2a51b1c.png
# correct_pneumonia :  592eba0f-e259-4a04-a574-05259f61fe5f.png
# correct_pneumonia :  cf419e9d-fc26-47d7-a05a-7d8444846724.png
# correct_pneumonia :  e509ea3f-3b0d-4364-8c1b-732ed409432c.png
# correct normal :  becced78-9df7-4e9a-94c8-7cb750d41507.png
# correct normal :  98c8bc72-1779-43f0-a118-538edcbc9e71.png
# correct normal :  203b7f39-41eb-4b06-ae00-387fbfa45dd8.png
# correct_pneumonia :  3b3e8c48-b34a-4cab-b217-7bcddfd5cd1a.png
# correct normal :  ba353385-091c-4c4a-8048-eca0388c7a43.png
# correct_pneumonia :  39276e28-456a-46f8-b74d-42601c7ec17e.png
# correct_pneumonia :  d73509a6-c0c2-4c8a-8e41-4c58eecfc035.png
# correct normal :  b58e15a4-085f-4d55-91e6-7d219ff570b5.png
# correct_pneumonia :  69399256-522e-4404-a4ff-67f49c711f8e.png
# correct normal :  ffd787b6-59ca-48cb-bd15-bcedd52cf37c.png
# correct normal :  1f458170-a4e7-447f-a157-2b44e85f1e6c.png
# correct normal :  ab514814-ddbf-46df-b913-650244f68f48.png
# correct normal :  7a5c7e58-8094-4ce4-94fa-e5e3e2fce6ab.png
# correct normal :  4f34c638-80de-4e77-92c7-87ccd0453b32.png
# correct normal :  0cde91a5-9428-4746-8240-f34c720e24cd.png
# correct normal :  b28af7c9-9cb3-4cd9-8261-0d1815d1609e.png
# correct_pneumonia :  15c2558a-5399-43f8-83c0-a36e634925bf.png
# correct_pneumonia :  14a17c79-36ac-4794-8f6b-797df627ea4d.png
# correct_pneumonia :  505db6f2-1a55-4766-b72d-120d1a6dfdee.png
# correct_pneumonia :  e910c042-111d-43b1-be8a-88e17f59c2c6.png
# correct_pneumonia :  4a42a757-7a81-4417-b0cc-00d8496f6531.png
# correct normal :  3c51d6fa-6fb9-41b9-b723-25121b75c306.png
# correct normal :  35f72695-d6d4-405a-8ddc-b64cbbca55ef.png
# correct normal :  7f29e031-874c-4ea2-9f7f-edc056cb5e83.png
# correct normal :  be27131b-ca91-4ba0-bf1c-7b6f9f57b4b0.png
# correct normal :  a57f578f-1e6f-4248-bd38-2dacfa772fdb.png
# correct normal :  5ead2889-223f-4fa3-a540-04495121c121.png
# correct_pneumonia :  f0fcd55d-33fd-4215-ace8-2f421db576bc.png
# correct normal :  7d402380-193a-4aef-92aa-8c80e11217fb.png
# correct normal :  e3884258-8083-4b8e-b952-9adc91a7f0f3.png
# correct normal :  34873b9f-5305-404e-b7f7-5105feede48a.png
# correct_pneumonia :  8d8b9e0a-56f2-46aa-8cc9-3535bd241ad3.png
# correct_pneumonia :  e54886f4-c110-4606-a543-f628b8cff558.png
# correct_pneumonia :  20705b50-3adb-4e95-bee6-e0fbd8f87776.png
# correct_pneumonia :  390197a9-db67-4dc0-95bb-3b57ce49c305.png
# correct_pneumonia :  8f8ec915-b753-4e10-8c17-936e2e548b56.png
# correct_pneumonia :  6a6cb2f1-eb9f-494e-b927-f4307af57060.png
# correct normal :  8062dc3e-fc3c-4e7e-b418-96c59942426d.png
# correct normal :  ca2ee113-9d1d-486c-aab0-ef51cb27c79e.png
# correct normal :  b039548f-9627-4701-951b-ae89efd3789f.png
# correct normal :  9de7304a-bda3-4aa7-8002-c7b1b662745d.png
# correct normal :  03d92597-3e33-4fdf-8db5-a27cf5b8d3eb.png
# correct_pneumonia :  f462597a-29bc-4693-b781-1f04036eba96.png
# correct normal :  c033f66d-900e-4ba3-8da4-a6823ea89d09.png
# correct_pneumonia :  5f9bfb92-2930-414a-bbeb-8f63a9c73de3.png
# correct normal :  b2103ba0-f721-45a3-876e-c4e53ebfe890.png
# correct normal :  091781dd-be2b-4517-9264-ade2f0c85487.png
# correct_pneumonia :  a9ed6265-89ba-4c5d-89f4-7df3ca2bf2fc.png
# correct_pneumonia :  4f36fdcd-1887-45b7-805f-2afffc3d10b3.png
# correct_pneumonia :  5420def8-80d8-4948-9c4e-456072874bf2.png
# correct_pneumonia :  7a58ecf6-9b13-4a3b-b27a-53365378156f.png
# correct normal :  ca390006-726d-4c9c-975b-616f135d0aee.png
# correct normal :  f7cc8800-27a2-4aca-b9d2-d07030ecbd7f.png
# correct_pneumonia :  e79fb9e0-c35d-4ea3-9e4b-126923129e28.png
# correct_pneumonia :  3d2863ff-7e64-4e52-bfd0-c71cf596bae5.png
# correct_pneumonia :  c19b8a3b-ab4e-4a73-8e13-ec0a84b6b6c7.png
# correct normal :  4b26d000-be82-4426-80f6-d129ff2e8c7c.png
# correct normal :  f5257a21-9efd-491f-94da-5cbce76d8f95.png
# correct normal :  4d64af6e-6810-4ca7-9b78-c8868a6ba248.png
# correct normal :  5003f421-e6d3-4c2c-b713-eba27a9078c2.png
# correct normal :  15cdd2b4-0fb2-482c-92ac-a640e94eccba.png
# correct normal :  4668a90c-d352-47d0-a3ac-a54aa8ce053b.png
# correct normal :  7b73919e-d14d-4f3c-88cd-e81a21ba756f.png
# correct_pneumonia :  174dea20-4712-4425-8328-b0a38e8f88ef.png
# correct_pneumonia :  5f71c85d-f8c7-4e05-89db-a61537dc3f97.png
# correct normal :  e3c0a6ca-58fb-4b9f-b56b-25491bbf3db8.png
# correct normal :  4d43c0dd-d87b-4ccf-83df-c82be5ea2aef.png
# correct normal :  bc87d74c-9d22-4046-ae17-5891adfa0b41.png
# correct_pneumonia :  eeabffdc-306a-46e2-b5b4-86dac89e1c4d.png
# correct_pneumonia :  d71abc0d-aaa8-4226-afc0-fc059b6d6a9f.png
# correct_pneumonia :  68fb70d8-304f-40a9-ac88-0d3103591093.png
# correct_pneumonia :  f2ca38b7-7222-4f3e-819d-c3c3713d9238.png
# correct normal :  95e6c3a5-1f34-4b87-8a71-a73032470fc0.png
# correct_pneumonia :  830f3bd1-2fdd-4823-9672-d864680db6f1.png
# correct normal :  9cbf0728-d245-4782-8aca-c25c5e8e158f.png
# correct_pneumonia :  5885c03d-7eb8-4472-8ad1-646e7d41fd48.png
# correct_pneumonia :  68c51c0c-777a-4e8a-9543-7f6a6101e6c9.png
# correct_pneumonia :  73a59a79-acad-42c5-8b91-b22ff7939cbb.png
# correct normal :  ae00e0cf-f575-44ce-8188-a611b464eb38.png
# correct_pneumonia :  7c077478-921d-4701-979e-b1d1bcb919eb.png
# correct_pneumonia :  827d6b20-ff1b-4db7-816a-96c333375b08.png
# correct normal :  f27e1121-c394-4577-80c6-762f47e916b2.png
# correct normal :  8a19e3ab-3b83-40d2-8ba3-40906f01c5a4.png
# correct normal :  efbaaa0c-da33-4200-a62e-d7d9d48c58ac.png
# correct_pneumonia :  6db9b51e-72d8-4511-b113-fa0ef0387fe3.png
# correct_pneumonia :  62ba66c2-7154-4b82-af96-09feb7b91e00.png
# correct normal :  8b8369dc-4085-4e1d-b1ca-5e1de60c15f0.png
# correct normal :  b090dd7d-b4d9-4ebe-b36d-95f83510e955.png
# correct normal :  6ed32587-0518-4b4b-95e6-a4b0651b1a6d.png
# correct_pneumonia :  41c5cb4a-4ebf-4774-b088-c14ea99f734d.png
# correct normal :  3a4bdc29-1bbf-4dd9-9fe7-00c42a081bc1.png
# correct normal :  a8b5a123-6dbd-412e-a871-12f4f65a6a05.png
# correct normal :  76f71a93-8105-4c79-a010-0cfa86f0061a.png
# correct_pneumonia :  03682e3c-d601-4e35-9ba5-06e85bba5c7c.png
# correct normal :  8c79e5d7-7862-4db1-8d88-062abff2e172.png
# correct_pneumonia :  29ce63f4-8e2d-4266-9b3d-00949aada503.png
# correct_pneumonia :  1467b120-791b-4d54-a7ac-26c3f2201891.png
# correct_pneumonia :  84fbfb70-4133-44c7-9c1d-67fc20d011df.png
# correct_pneumonia :  b6a763e0-aa38-49b5-a256-e119e8a90c39.png
# correct_pneumonia :  c44c6b39-ad2c-4b37-bd08-4b3ab81166a8.png
# correct_pneumonia :  d0ab662d-827a-456d-ae90-f1aa5f7e3650.png
# correct_pneumonia :  51702d7b-bbda-42f0-90a8-cb7cb1812a58.png
# correct normal :  b5eebe73-0b9c-4621-abcd-940f6e90a86c.png
# correct_pneumonia :  6f869ebd-15ca-4d46-89b1-0c0a3d367124.png
# correct_pneumonia :  60c7d6a1-9aad-452f-9789-918056b955ad.png
# correct normal :  99dfce1b-ea95-4bc5-b162-dd891968dae1.png
# correct normal :  21afc084-1c98-42f5-b767-edb5cb8f2884.png
# correct_pneumonia :  c3d0505a-4e8e-42d7-b3d7-f9ab077465ec.png
# correct normal :  e9d5d7c2-0f97-4084-8702-1704e44083b6.png
# correct_pneumonia :  d9431971-23aa-451e-a643-a95ce034c3d3.png
# correct normal :  da69ffb8-40fa-49ea-b11e-9ddff40845e8.png
# correct normal :  ab1131b2-d179-4087-b32b-463a3e615ba6.png
# correct_pneumonia :  09854bb5-4fed-43e2-96cf-8f24ca71cb6e.png
# correct_pneumonia :  7de9b008-f6a8-4101-965d-8590ceaa808a.png
# correct_pneumonia :  cf3b5e4b-043c-4fcf-81b5-c11898dcefe8.png
# correct_pneumonia :  54fc4986-daf1-49c9-8309-0be488ebc9f8.png
# correct normal :  ed38283d-165f-481b-bbb3-5532450b82c1.png
# correct normal :  b3f132cb-438b-40d4-a951-0089e8b1a840.png
# correct_pneumonia :  65139428-111f-4e09-82a6-14fafe18cbbe.png
# correct normal :  f760c946-a103-4991-a6e5-ff60c24cd99f.png
# correct_pneumonia :  c28a09eb-b266-4625-b6d0-74f6003b7fc5.png
# correct normal :  3164b8ce-f84e-47db-9c14-e78890c955ed.png
# correct normal :  aac8b420-f849-4c60-8486-0155f282633b.png
# correct_pneumonia :  cb4f3549-edf8-4eda-9172-64a7af4223dc.png
# correct_pneumonia :  7a543f64-6596-4944-ae8a-d21cc0644823.png
# correct_pneumonia :  7f2a78a7-71ce-4eec-a427-b31e447e068f.png
# correct_pneumonia :  44ef7542-d997-4d06-adeb-9f72a5588d47.png
# correct normal :  c4328895-fac4-4ecc-b164-88f77dee37ca.png
# correct normal :  3fc3e7fb-1fff-4ad0-9900-8874ada57d05.png
# correct normal :  b86e6759-681b-4846-a51a-9f6ec523d633.png
# correct normal :  8b6be652-97a4-4149-bd5a-92464ba031ef.png
# correct_pneumonia :  c5da93bd-dbe2-41aa-8f3a-6c9b3740202e.png
# correct normal :  f6cfde90-10de-4584-aed1-2a0ef8238b11.png
# correct_pneumonia :  9cd4233f-b8c0-4c4f-82f2-5b7cfe3255d1.png
# correct normal :  39b06cc3-1e49-4459-bb87-b8b69bbe74d7.png
# correct_pneumonia :  cf746da1-6346-4389-878e-da7d674ea693.png
# correct normal :  b852bc3c-0de5-4448-aff8-f96b2cc13d51.png
# correct normal :  6672d139-1fd5-42d4-9c2c-55b25002e6ed.png
# correct normal :  06d6e209-0bd4-45d4-81b4-4b97546d57fa.png
# correct_pneumonia :  9bc9e813-e815-42a1-aed6-c24e45d59ea4.png
# correct normal :  a0f962a9-f02a-47ed-894b-392e571994e8.png
# correct_pneumonia :  3ea80a73-44fc-4b9e-946a-ebd620e004fe.png
# correct_pneumonia :  d0538050-719b-43ab-9160-4ae850c9a949.png
# correct normal :  3f151141-a3bb-47aa-a213-4a90e8c55502.png
# correct_pneumonia :  913802e2-820b-49e9-a48c-ec32949c1e8e.png
# correct_pneumonia :  2e12816f-48d5-4a6c-a8ac-c3c2ae7ba059.png
# correct normal :  3d1a1f04-fc3b-4635-b1e5-1c7ab62f20e6.png
# correct normal :  6a778bf7-2bbd-4804-9d81-38eca7019ffe.png
# correct_pneumonia :  427f7983-089b-4041-9772-e92b75d7e202.png
# correct_pneumonia :  07cdb450-541e-4810-900b-b3b7b9846e8b.png
# correct_pneumonia :  bad5f195-a3ca-4ee0-b91f-57092abb4b5a.png
# correct normal :  bbe15fbc-e79c-4206-a901-5b23888f8a8b.png
# correct_pneumonia :  e6142222-d9bd-406b-a02f-59941a56eaf0.png
# correct normal :  d7ccc813-9dab-48c3-bf30-c6d305c85a4a.png
# correct_pneumonia :  8b0c0155-5275-490c-9863-0ff9168dce7a.png
# correct_pneumonia :  a304f66c-0229-4c8e-917f-2659b7a6e70d.png
# correct normal :  06550cfd-e9d5-415e-bae9-3146329ed9e6.png
# correct_pneumonia :  512db933-7149-4da3-97dc-735eb7987802.png
# correct normal :  911a46a2-4371-4012-9f0c-c3b2b323c4fd.png
# correct_pneumonia :  e146d776-a1b8-4e16-a32e-ef0e6b1d7aad.png
# correct_pneumonia :  57fe22d0-170e-4f00-ba97-1b899ba8bea6.png
# correct_pneumonia :  c5b56560-0d82-4161-b5c1-5e5051a70c37.png
# correct_pneumonia :  bf0d5b47-c5e0-41ad-8c1a-e9ac6dab9ff9.png
# correct_pneumonia :  ece14845-36ed-4e3b-809b-dff4bfd063fe.png
# correct normal :  adf7dc8f-19dc-4543-8aea-982cfa21629b.png
# correct normal :  5f40e828-88a4-4f07-8286-b5446f4d4790.png
# correct normal :  4cbb68e5-1ca0-4a2a-b3d2-022110364d7c.png
# correct_pneumonia :  89aeafbd-37ed-4ff7-a8cf-3e6e5cf803ef.png
# correct_pneumonia :  7ddece1d-137e-486e-a19b-8fce32365127.png
# correct_pneumonia :  dd5877f4-0c0f-40a7-b38e-48571110c728.png
# correct_pneumonia :  9bf09456-da28-4206-9e8b-fc076b5fc0f3.png
# correct_pneumonia :  49dcbed5-1a06-477c-ae64-46b6391d7774.png
# correct normal :  8c6af598-175a-497b-8938-02c432afd70d.png
# correct_pneumonia :  895b0c0e-75cb-4adc-9203-3d48ce3404f5.png
# correct normal :  a0af1a60-0f1c-4d53-9a71-dd438aa06b70.png
# correct normal :  ca8b395d-7ca0-4dc4-8b56-ff519b4edb89.png
# correct_pneumonia :  01be3fe5-4a91-4c57-9af6-305966a7d0aa.png
# correct normal :  8aa2f1cd-a9f5-4f10-8dd7-1d40b2fbaf50.png
# correct normal :  56b6f280-7857-4623-8f9d-4f0c69dc71a6.png
# correct normal :  acea0494-388b-4745-a430-892751494e8c.png
# correct_pneumonia :  d8de4b4a-2c63-4959-8781-307de9233934.png
# correct normal :  6a377640-4f7d-4f15-868a-91dfca7d6651.png
# correct_pneumonia :  a392cdea-a4ca-4eb5-9922-ca15f9db0cee.png
# correct_pneumonia :  7c5d3a49-2f55-4d46-9357-0a2bba2fc63e.png
# correct normal :  c600753e-3394-4e74-9f7c-6687891aacc4.png
# correct_pneumonia :  1e334125-d0bf-4229-bf47-c7739ec3bf5b.png
# correct_pneumonia :  cb02fb32-08e3-4d2c-b81e-75fb77019f78.png
# correct_pneumonia :  d1fd9bfb-f626-4fb2-bb0d-b22cd64dbd1f.png
# correct_pneumonia :  feb64d56-3824-4df5-8ca0-72f146dc3aca.png
# correct_pneumonia :  de25af7b-367b-4682-a9b5-e7f410511875.png
# correct normal :  53872ba6-efa0-456f-80bd-bdb4ed66fc59.png
# correct normal :  2fa8e28a-dce6-4c68-8bb6-b2537476577d.png
# correct_pneumonia :  c5e27628-afd5-4681-b8dd-ca630472dfba.png
# correct_pneumonia :  7c84bee5-a16e-48c7-b84a-6b61b0d62ce9.png
# correct_pneumonia :  3141838c-603b-47ea-8591-80a7e7c5bf12.png
# correct normal :  71c5e5fa-6d92-44a3-a9fa-1e3421b27a07.png
# correct_pneumonia :  698e0d36-b52f-41d2-a65a-b42bbcf67b2a.png
# correct normal :  fef7b294-017c-4491-9e57-119086855785.png
# correct_pneumonia :  bb3c0af5-2fd4-4099-a68d-f0c0e492616c.png
# correct_pneumonia :  35ba6cd0-4faa-4fb3-a25f-49295d0fd33c.png
# correct normal :  408c1583-d078-45f4-9369-2fbaf03be8a8.png
# correct normal :  bfe7e758-97b3-4763-a91b-8bf559c143a4.png
# correct normal :  b41dfb17-3773-485b-8da6-c29a2bbfbe3a.png
# correct normal :  7c1d3e58-174d-450f-9f19-caad0cdce430.png
# correct_pneumonia :  34ac4072-4a44-4a08-bc4e-5978785d8283.png
# correct normal :  ba1dd94b-afbe-4b09-a188-8ea1098d4848.png
# correct_pneumonia :  38a2d9bc-5487-4abd-8431-698574ab58be.png
# correct_pneumonia :  e5bd8650-d4f6-4f8f-b3ac-fed31a1cbd7d.png
# correct normal :  06cc46b7-50b1-41c1-a406-ccac7a5ac3e2.png
# correct_pneumonia :  763f991b-5a8a-47d0-9b9f-151cc661218d.png
# correct_pneumonia :  4e14472a-20d8-4c6a-9322-d8977e0948c4.png
# correct_pneumonia :  329e55d1-2e27-4ffe-95b1-df5f5015aae6.png
# correct normal :  7c9248d5-b2bc-4359-9667-108109a2de2e.png
# correct normal :  00aecb01-a116-45a2-956c-08d2fa55433f.png
# correct_pneumonia :  a2b64497-d2c0-4de4-ac19-75bb9506f96b.png
# correct_pneumonia :  cdfd8330-743d-473f-a738-d4e42ba678a3.png
# correct normal :  711b8e6a-0406-4c61-8c13-3e90fd7ecba1.png
# correct_pneumonia :  eb95bd9c-4352-4a34-8f47-3c57db6998ce.png
# correct normal :  7507bb99-a8cf-48c8-a4dd-859ad26e9e1a.png
# correct normal :  f8767c5d-9024-43d9-9044-843f2cec00c7.png
# correct normal :  5b9d346b-8f6e-4ebf-8865-0c1ff9baac49.png
# correct_pneumonia :  9e9f1dfe-7412-4fef-9f6d-f344e157815c.png
# correct normal :  31e2cf57-392d-4fdf-97ce-69a2da281eec.png
# correct_pneumonia :  f04fe181-ce05-4610-a226-dd6a44107f43.png
# correct normal :  0b8e881f-67bc-4021-a02c-0087233e43aa.png
# correct_pneumonia :  3fd5687e-bc16-4802-a44e-163f667882e4.png
# correct normal :  d877d8be-7d38-43aa-b359-bd86cf3951c3.png
# correct normal :  22e76fb4-c74e-4cc3-820a-832a4467dac6.png
# correct normal :  098906c5-cf22-43d3-9f0d-90e88e602090.png
# correct normal :  05d4d725-02a2-4c90-8ef8-463217889ba8.png
# correct_pneumonia :  5503ca33-0018-468a-a0a1-c5d8b8bf8321.png
# correct_pneumonia :  ffb0a415-cd40-4c33-b806-cf533505f89e.png
# correct normal :  ba06c828-df8c-4c6f-a869-b3ea7d1991cd.png
# correct normal :  0b7a4fb2-adab-484b-a0f7-23f5111bc745.png
# correct normal :  bce1fe53-1047-4dfe-9444-bc8340cddabf.png
# correct normal :  340244af-50e9-405f-85af-7fe6c8e0f838.png
# correct normal :  19add6b5-7856-415a-9a44-e2bfda767339.png
# correct normal :  ebd9a666-b3ff-407c-9d50-9af3a285304f.png
# correct normal :  13ef2d8e-3b2e-4fbb-9f70-69139dd74401.png
# correct normal :  36b750d4-ac1c-4301-addb-bb00f6edad82.png
# /content/SGCR/modelsupdated_model-1565683011.json
# Saved model to disk
